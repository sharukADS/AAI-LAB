# %%
import urllib.request

url = "https://i.imgur.com/8vuLtqi.png"  # sample stationery image
urllib.request.urlretrieve(url, "stationery.jpg")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_2626/1435847850.py in <cell line: 0>()
#       2
#       3 url = "https://i.imgur.com/8vuLtqi.png"  # sample stationery image
# ----> 4 urllib.request.urlretrieve(url, "stationery.jpg")
#
# /usr/lib/python3.12/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     238     url_type, path = _splittype(url)
#     239
# --> 240     with contextlib.closing(urlopen(url, data)) as fp:
#     241         headers = fp.info()
#     242
#
# /usr/lib/python3.12/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     else:
#     214         opener = _opener
# --> 215     return opener.open(url, data, timeout)
#     216
#     217 def install_opener(opener):
#
# /usr/lib/python3.12/urllib/request.py in open(self, fullurl, data, timeout)
# ...

# %%
import urllib.request

url = "https://raw.githubusercontent.com/opencv/opencv/master/samples/data/fruits.jpg"
urllib.request.urlretrieve(url, "stationery.jpg")
# Out:
# ('stationery.jpg', <http.client.HTTPMessage at 0x79ad2b99c860>)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c854bf67-1024-4448-897e-54e553a05495" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c854bf67-1024-4448-897e-54e553a05495">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

image = cv2.imread('/content/drive/MyDrive/stationery.jpg')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

path = "/content/drive/MyDrive/Stationery dataset"
print(os.listdir(path))
# Out:
# ['170.jpg', '243.jpg', '219.jpg', '216.txt', '229.txt', '249.jpg', '199.jpg', '184.txt', '132.txt', '10.jpg', '13.txt', '159.jpg', '13.jpg', '217.txt', '136.jpg', '162.jpg', '237.jpg', '179.txt', '167.jpg', '131.txt', '248.txt', '246.jpg', '143.txt', '249.txt', '157.jpg', '239.txt', '167.txt', '211.txt', '147.jpg', '196.jpg', '141.jpg', '192.jpg', '225.jpg', '180.jpg', '24.txt', '12.txt', '11.txt', '240.txt', '239.jpg', '154.jpg', '1.jpg', '143.jpg', '253.txt', '148.jpg', '224.jpg', '238.txt', '151.jpg', '237.txt', '235.jpg', '148.txt', '203.txt', '138.jpg', '205.txt', '16.txt', '204.txt', '1.txt', '156.jpg', '166.txt', '139.txt', '11.jpg', '255.txt', '245.txt', '234.txt', '12.jpg', '213.jpg', '221.jpg', '205.jpg', '188.jpg', '176.txt', '17.jpg', '209.txt', '188.txt', '145.txt', '135.jpg', '193.txt', '202.txt', '154.txt', '22.txt', '187.txt', '218.txt', '236.txt', '179.jpg', '155.txt', '209.jpg', '168.jpg', '213.txt', '201.jpg', '217.jpg', '174.jpg', '158.jpg', '202.jpg', '2.png', '2
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.1 MB/s eta 0:00:00
# ...

# %%
dataset_path = "/content/drive/MyDrive/Stationery dataset"

yaml_content = f"""
path: {dataset_path}
train: .
val: .

names:
  0: object
"""

with open("dataset.yaml", "w") as f:
    f.write(yaml_content)

print("✅ dataset.yaml created")
# Out:
# ✅ dataset.yaml created

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="dataset.yaml",
    epochs=10,
    imgsz=640
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
import cv2
import matplotlib.pyplot as plt

model = YOLO("runs/detect/train/weights/best.pt")

img_path = "/content/drive/MyDrive/Stationery dataset/1.jpg"

results = model(img_path)

img = cv2.imread(img_path)

count = 0

for r in results:
    for box in r.boxes:
        count += 1

        x1, y1, x2, y2 = map(int, box.xyxy[0])

        cv2.rectangle(img, (x1,y1), (x2,y2), (0,255,0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title(f"Total Objects: {count}")
plt.axis("off")
# Out:
# image 1/1 /content/drive/MyDrive/Stationery dataset/1.jpg: 640x576 (no detections), 209.3ms
# Speed: 4.1ms preprocess, 209.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
# (np.float64(-0.5), np.float64(212.5), np.float64(249.5), np.float64(-0.5))

# %%
dataset_path = "/content/drive/MyDrive/Stationery dataset"

yaml_content = f"""
path: {dataset_path}
train: .
val: .

names:
  0: pen
  1: pencil
  2: eraser
  3: ruler
  4: notebook
"""

with open("dataset.yaml", "w") as f:
    f.write(yaml_content)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="dataset.yaml",
    epochs=15,
    imgsz=640
)
# Out:
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load trained model
model = YOLO("runs/detect/train/weights/best.pt")

img_path = "/content/drive/MyDrive/Stationery dataset/1.jpg"

results = model(img_path)
img = cv2.imread(img_path)

# 🔥 Dictionary for counting
counts = {}

for r in results:
    for box in r.boxes:
        cls = int(box.cls[0])
        label = model.names[cls]

        # Count each class
        if label not in counts:
            counts[label] = 0
        counts[label] += 1

        # Draw box
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        cv2.rectangle(img, (x1,y1), (x2,y2), (0,255,0), 2)
        cv2.putText(img, label, (x1,y1-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,0,0), 2)

# Show image
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")

# 🔥 Print counts
print("Object Counts:")
for k, v in counts.items():
    print(f"{k}: {v}")
# Out:
# image 1/1 /content/drive/MyDrive/Stationery dataset/1.jpg: 640x576 (no detections), 344.6ms
# Speed: 4.8ms preprocess, 344.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
# Object Counts:

# %%
pixelsPerMetric = None
object_count = 0

def midpoint(ptA, ptB):
    return ((ptA[0]+ptB[0])*0.5, (ptA[1]+ptB[1])*0.5)

for c in cnts:
    if cv2.contourArea(c) < 500:
        continue

    object_count += 1

    box = cv2.minAreaRect(c)
    box = cv2.boxPoints(box)
    box = np.array(box, dtype="int")

    box = perspective.order_points(box)
    (tl, tr, br, bl) = box

    (tltrX, tltrY) = midpoint(tl, tr)
    (blbrX, blbrY) = midpoint(bl, br)
    (tlblX, tlblY) = midpoint(tl, bl)
    (trbrX, trbrY) = midpoint(tr, br)

    dA = np.linalg.norm([tltrX-blbrX, tltrY-blbrY])
    dB = np.linalg.norm([tlblX-trbrX, tlblY-trbrY])

    # IMPORTANT: Reference object (RULER)
    if pixelsPerMetric is None:
        known_width = 15.0  # change based on your ruler
        pixelsPerMetric = dB / known_width

    dimA = dA / pixelsPerMetric
    dimB = dB / pixelsPerMetric

    cv2.drawContours(orig, [box.astype("int")], -1, (0,255,0), 2)

    cv2.putText(orig, "{:.1f}cm".format(dimA),
                (int(tltrX), int(tltrY-10)),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)

    cv2.putText(orig, "{:.1f}cm".format(dimB),
                (int(trbrX+10), int(trbrY)),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7de88f5d-17dd-42e5-8b07-666c5d7cef03" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7de88f5d-17dd-42e5-8b07-666c5d7cef03">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load pretrained model
model = YOLO("yolov8n.pt")

# Use your uploaded image name (change if needed)
img_path = list(uploaded.keys())[0]

# Run detection
results = model(img_path)

# Read image
img = cv2.imread(img_path)

count = 0

# Process results
for r in results:
    for box in r.boxes:
        count += 1

        x1, y1, x2, y2 = map(int, box.xyxy[0])
        cls = int(box.cls[0])
        label = model.names[cls]

        # Draw box
        cv2.rectangle(img, (x1,y1), (x2,y2), (0,255,0), 2)
        cv2.putText(img, label, (x1,y1-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)

# Show image
plt.figure(figsize=(8,8))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title(f"Total Objects Counted: {count}")
plt.axis("off")

print("Total Objects:", count)
# Out:
# image 1/1 /content/img.jpg: 448x640 3 scissorss, 2 toothbrushs, 193.3ms
# Speed: 4.0ms preprocess, 193.3ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# Total Objects: 5
